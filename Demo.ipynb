# %% [markdown]
# # <a href="https://colab.research.google.com/github/Duc-Tam-Huynh/Yolo5b/blob/master/Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Duc-Tam-Huynh/Yolo5b
# Out:
# Cloning into 'Yolo5b'...
# remote: Enumerating objects: 515, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 515 (delta 2), reused 0 (delta 0), pack-reused 506
# Receiving objects: 100% (515/515), 11.98 MiB | 29.63 MiB/s, done.
# Resolving deltas: 100% (67/67), done.

# %%
# !pip install -r /content/Yolo5b/yolov5/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.6 MB/s eta 0:00:00
# ...

# %%
# !python /content/Yolo5b/yolov5/train.py --img 416 --batch 16   --epochs 200 --data coco128.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=Yolo5b/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Yolo5b/yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2023-5-2 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# kiem tra '/content/yolov5/runs/train/exp4/weights/best.pt' trong file detect.py
# !python /content/Yolo5b/yolov5/detect.py --source /content/Yolo5b/rifle1.jpg
# Out:
# detect: weights=/content/Yolo5b/yolov5/runs/train/exp/weights/best.pt, source=/content/Yolo5b/rifle1.JPG, data=Yolo5b/yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=Yolo5b/yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2023-5-2 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/Yolo5b/rifle1.JPG: 544x640 2 rifles, 39.0ms
# Speed: 0.5ms pre-process, 39.0ms inference, 1.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to Yolo5b/yolov5/runs/detect/exp2

# %%
# !python /content/Yolo5b/yolov5/detect.py --source /content/Yolo5b/pistol.jpg
# Out:
# detect: weights=/content/Yolo5b/yolov5/runs/train/exp/weights/best.pt, source=/content/Yolo5b/pistol.JPG, data=Yolo5b/yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=Yolo5b/yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2023-5-2 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/Yolo5b/pistol.JPG: 416x640 2 pistols, 40.3ms
# Speed: 0.4ms pre-process, 40.3ms inference, 1.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to Yolo5b/yolov5/runs/detect/exp12

# %%
# !python /content/Yolo5b/yolov5/detect.py --source /content/Yolo5b/custom_dataset/images_and_labels/images/test
# Out:
# detect: weights=/content/Yolo5b/yolov5/runs/train/exp/weights/best.pt, source=/content/Yolo5b/custom_dataset/images_and_labels/images/test, data=Yolo5b/yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=Yolo5b/yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2023-5-2 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/5 /content/Yolo5b/custom_dataset/images_and_labels/images/test/a1.JPG: 640x544 (no detections), 59.0ms
# image 2/5 /content/Yolo5b/custom_dataset/images_and_labels/images/test/a2.JPG: 576x640 (no detections), 60.0ms
# ...

# %%
# !python /content/Yolo5b/yolov5/detect.py --source 'https://www.youtube.com/watch?v=xGB-sXn3DJ0'
# Out:
# Streaming output truncated to the last 5000 lines.
# 0: 384x640 1 rifle, 8.6ms
# 0: 384x640 1 rifle, 9.3ms
# 0: 384x640 1 rifle, 9.5ms
# 0: 384x640 1 rifle, 6.8ms
# 0: 384x640 1 rifle, 6.8ms
# 0: 384x640 1 rifle, 6.8ms
# 0: 384x640 1 rifle, 6.6ms
# 0: 384x640 1 rifle, 6.9ms
# 0: 384x640 1 rifle, 6.8ms
# 0: 384x640 1 rifle, 7.0ms
# 0: 384x640 1 rifle, 24.1ms
# 0: 384x640 1 rifle, 7.3ms
# 0: 384x640 1 rifle, 8.2ms
# 0: 384x640 1 rifle, 8.0ms
# 0: 384x640 1 rifle, 7.0ms
# 0: 384x640 1 rifle, 6.6ms
# 0: 384x640 1 rifle, 6.9ms
# 0: 384x640 1 rifle, 6.6ms
# 0: 384x640 1 rifle, 6.7ms
# 0: 384x640 1 rifle, 6.6ms
# 0: 384x640 1 rifle, 6.7ms
# 0: 384x640 1 rifle, 8.0ms
# 0: 384x640 1 rifle, 6.6ms
# 0: 384x640 1 rifle, 14.2ms
# 0: 384x640 (no detections), 9.8ms
# 0: 384x640 (no detections), 6.9ms
# 0: 384x640 (no detections), 6.6ms
# 0: 384x640 (no detections), 6.8ms
# 0: 384x640 (no detections), 6.9ms
# 0: 384x640 (no detections), 6.8ms
# 0: 384x640 (no detections), 6.9ms
# ...
